# %%
import json
with open('/Users/admin/.secret/yelp_api.json') as f: #change the path to match YOUR path!!
    login = json.load(f)
login.keys()
# Out:
# dict_keys(['client-id', 'api-key'])

# %%
pip install yelpapi
# Out:
# Requirement already satisfied: yelpapi in c:\users\admin\anaconda3\envs\dojo-env\lib\site-packages (2.5.0)
# Requirement already satisfied: requests in c:\users\admin\anaconda3\envs\dojo-env\lib\site-packages (from yelpapi) (2.31.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\admin\anaconda3\envs\dojo-env\lib\site-packages (from requests->yelpapi) (1.26.13)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\admin\anaconda3\envs\dojo-env\lib\site-packages (from requests->yelpapi) (2022.9.24)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\admin\anaconda3\envs\dojo-env\lib\site-packages (from requests->yelpapi) (3.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\admin\anaconda3\envs\dojo-env\lib\site-packages (from requests->yelpapi) (2.0.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
# import the YelpAPI Class
from yelpapi import YelpAPI
# Create an instance with your key
yelp_api = YelpAPI(login['api-key'], timeout_s=5.0)
yelp_api

# %%
# Define Location and term for search

LOCATION = "San Antonio, TX"
TERM = "Thai"

# use our yelp_api variable's search_query method to perform our API call
search_results = yelp_api.search_query(location='San Antonio, TX',
                                       term='Thai')
print(type(search_results))
search_results.keys()
# Out:
# <class 'dict'>
# dict_keys(['businesses', 'total', 'region'])

# %%
# VIew total number of search results returned
total_results = search_results['total']

total_results
# Out:
# 308

# %%
import pandas as pd
# View search results as dataframe
biz = pd.DataFrame(search_results['businesses'])
biz.head(20)
# Out:
#                         id                                              alias  \
# 0   2vfKC87Dy5Z7Umk8XMiHig                bangkok-54-thai-cuisine-san-antonio
# 1   vCXT8MFy4U8pW0ZmgoM9Xg                  tongs-thai-restaurant-san-antonio
# 2   QOSNw732x0Uc-3yM9jOJfg                               thai-dee-san-antonio
# 3   KG7ORua_tyiOgOKva9rWww                   thai-buri-restaurant-san-antonio
# 4   YEEThW_KpCte5TTNeFm9Cw                  sawasdee-thai-cuisine-san-antonio
# 5   QMtcGkDTL8xGtl-9EhVviA                thai-bistro-and-sushi-san-antonio-3
# 6   hlS8aD3tPmKLstQObPYxHA                  thai-curry-restaurant-san-antonio
# 7   kNm5NxIwTG5JspGGHCrUfA                         thai99-express-san-antonio
# 8   h8RUrgghqoS1sn5ADC5gbg  sukhothai-thai-restaurant-express-3-san-antonio-2
# 9   5mNgT9cQRvFgH-PbXmW_2A                  thai-house-restaurant-san-antonio
# 10  1tfTC3wv-x2YN0jXIxkoFQ                 yayas-thai-restaurant-olmos-park-2
# 11  bNe_TE_QVBYhWX6TiayOLA                  thai-casa-on-broadway-san-antonio
# 12  XbL1p41FDLRYpjpVajVLpQ                     sabai-thai-kitchen-san-antonio
# 13  3hM5fxiV1KOM8iDf0TJfVw               thai-topaz-san-antonio-san-antonio-5
# 14  ye3MkmmkB6i2uMERiZDkGA                             thai-lucky-san-antonio
# 15  i8rBpr8KJq2wLSAQrGsI7Q                  noppagao-thai-cuisine-san-antonio
# 16  Rw5MRYU_J7Pew033C5_pUg    sukhothai-thai-restaurant-express-san-antonio-5
# 17  Ja3BB1rHlVVD4pFkv77AQg              sukhothai-thai-restaurant-san-antonio
# 18  6AfFjEzmNWQgy4sBuTTmag                 thai-house2-restaurant-san-antonio
# 19  RBVDzd2fpMXmzuP5FP4KJQ                             tasty-thai-san-antonio
#
#                                    name  \
# 0               Bangkok 54 Thai Cuisine
# 1                Tong's Thai Restaurant
# 2                              Thai Dee
# 3                  Thai Buri Restaurant
# 4                 Sawasdee Thai Cuisine
# 5                   Thai Bistro & Sushi
# 6                Thai Curry Restaurant
# 7                        Thai99 Express
# 8   Sukhothai Thai Restaurant Express 3
# 9                 Thai House Restaurant
# 10               YaYa's Thai Restaurant
# 11                Thai Casa On Broadway
# 12                   Sabai Thai Kitchen
# 13             Thai Topaz - San Antonio
# 14                           Thai Lucky
# 15                Noppagao Thai Cuisine
# 16    Sukhothai Thai Restaurant Express
# 17            Sukhothai Thai Restaurant
# 18               Thai House2 Restaurant
# 19                           Tasty Thai
#
#                                             image_url  is_closed  \
# 0   https://s3-media1.fl.yelpcdn.com/bphoto/vzYl-G...      False
# 1   https://s3-media4.fl.yelpcdn.com/bphoto/QASd7c...      False
# 2   https://s3-media4.fl.yelpcdn.com/bphoto/uQCxup...      False
# 3   https://s3-media2.fl.yelpcdn.com/bphoto/5wUOyx...      False
# 4   https://s3-media2.fl.yelpcdn.com/bphoto/LXPinj...      False
# 5   https://s3-media3.fl.yelpcdn.com/bphoto/_3O7vl...      False
# 6   https://s3-media1.fl.yelpcdn.com/bphoto/y_bV7G...      False
# 7   https://s3-media4.fl.yelpcdn.com/bphoto/30VSi8...      False
# 8   https://s3-media1.fl.yelpcdn.com/bphoto/vB07re...      False
# 9   https://s3-media2.fl.yelpcdn.com/bphoto/Y_apUg...      False
# 10  https://s3-media3.fl.yelpcdn.com/bphoto/AHZmG5...      False
# 11  https://s3-media4.fl.yelpcdn.com/bphoto/g_CAdf...      False
# 12  https://s3-media4.fl.yelpcdn.com/bphoto/4wN8pg...      False
# 13  https://s3-media4.fl.yelpcdn.com/bphoto/hJEN3r...      False
# 14  https://s3-media4.fl.yelpcdn.com/bphoto/4r8MTz...      False
# 15  https://s3-media3.fl.yelpcdn.com/bphoto/bQ1V76...      False
# 16  https://s3-media2.fl.yelpcdn.com/bphoto/y9Mg-R...      False
# 17  https://s3-media2.fl.yelpcdn.com/bphoto/sF5Iqq...      False
# 18  https://s3-media2.fl.yelpcdn.com/bphoto/uEGHGQ...      False
# 19  https://s3-media4.fl.yelpcdn.com/bphoto/pRL-21...      False
#
#                                                   url  review_count  \
# 0   https://www.yelp.com/biz/bangkok-54-thai-cuisi...           384
# 1   https://www.yelp.com/biz/tongs-thai-restaurant...           846
# 2   https://www.yelp.com/biz/thai-dee-san-antonio?...           605
# 3   https://www.yelp.com/biz/thai-buri-restaurant-...           156
# 4   https://www.yelp.com/biz/sawasdee-thai-cuisine...           343
# 5   https://www.yelp.com/biz/thai-bistro-and-sushi...           551
# 6   https://www.yelp.com/biz/thai-curry-restaurant...            27
# 7   https://www.yelp.com/biz/thai99-express-san-an...            12
# 8   https://www.yelp.com/biz/sukhothai-thai-restau...            18
# 9   https://www.yelp.com/biz/thai-house-restaurant...           266
# 10  https://www.yelp.com/biz/yayas-thai-restaurant...           232
# 11  https://www.yelp.com/biz/thai-casa-on-broadway...            90
# 12  https://www.yelp.com/biz/sabai-thai-kitchen-sa...            39
# 13  https://www.yelp.com/biz/thai-topaz-san-antoni...           360
# 14  https://www.yelp.com/biz/thai-lucky-san-antoni...           335
# 15  https://www.yelp.com/biz/noppagao-thai-cuisine...            73
# 16  https://www.yelp.com/biz/sukhothai-thai-restau...           175
# 17  https://www.yelp.com/biz/sukhothai-thai-restau...           208
# 18  https://www.yelp.com/biz/thai-house2-restauran...           152
# 19  https://www.yelp.com/biz/tasty-thai-san-antoni...           105
#
#                                            categories  rating  \
# 0                [{'alias': 'thai', 'title': 'Thai'}]     4.5
# 1   [{'alias': 'thai', 'title': 'Thai'}, {'alias':...     4.0
# 2   [{'alias': 'thai', 'title': 'Thai'}, {'alias':...     4.0
# 3   [{'alias': 'thai', 'title': 'Thai'}, {'alias':...     4.5
# 4                [{'alias': 'thai', 'title': 'Thai'}]     4.0
# 5                [{'alias': 'thai', 'title': 'Thai'}]     4.0
# 6   [{'alias': 'thai', 'title': 'Thai'}, {'alias':...     5.0
# 7                [{'alias': 'thai', 'title': 'Thai'}]     5.0
# 8   [{'alias': 'thai', 'title': 'Thai'}, {'alias':...     4.5
# 9                [{'alias': 'thai', 'title': 'Thai'}]     4.5
# 10               [{'alias': 'thai', 'title': 'Thai'}]     4.0
# 11  [{'alias': 'thai', 'title': 'Thai'}, {'alias':...     4.5
# 12               [{'alias': 'thai', 'title': 'Thai'}]     4.5
# 13  [{'alias': 'thai', 'title': 'Thai'}, {'alias':...     4.0
# 14               [{'alias': 'thai', 'title': 'Thai'}]     4.0
# 15               [{'alias': 'thai', 'title': 'Thai'}]     4.5
# 16  [{'alias': 'thai', 'title': 'Thai'}, {'alias':...     4.5
# 17  [{'alias': 'thai', 'title': 'Thai'}, {'alias':...     4.5
# 18               [{'alias': 'thai', 'title': 'Thai'}]     4.5
# 19  [{'alias': 'thai', 'title': 'Thai'}, {'alias':...     3.5
#
#                                           coordinates  \
# 0   {'latitude': 29.5187911987305, 'longitude': -9...
# 1   {'latitude': 29.4867884, 'longitude': -98.448251}
# 2      {'latitude': 29.49933, 'longitude': -98.50813}
# 3   {'latitude': 29.606784414437673, 'longitude': ...
# 4   {'latitude': 29.5136301, 'longitude': -98.5069...
# 5      {'latitude': 29.56338, 'longitude': -98.60091}
# 6      {'latitude': 29.51166, 'longitude': -98.46587}
# 7   {'latitude': 29.58491475010856, 'longitude': -...
# 8    {'latitude': 29.485357, 'longitude': -98.724984}
# 9   {'latitude': 29.4842834472656, 'longitude': -9...
# 10  {'latitude': 29.4797677693933, 'longitude': -9...
# 11   {'latitude': 29.518245, 'longitude': -98.464827}
# 12  {'latitude': 29.625648016638483, 'longitude': ...
# 13   {'latitude': 29.532583, 'longitude': -98.521614}
# 14  {'latitude': 29.411597440870636, 'longitude': ...
# 15  {'latitude': 29.504321301390952, 'longitude': ...
# 16     {'latitude': 29.51146, 'longitude': -98.66207}
# 17  {'latitude': 29.3798747130714, 'longitude': -9...
# 18     {'latitude': 29.50205, 'longitude': -98.55907}
# 19   {'latitude': 29.580055, 'longitude': -98.475225}
#
#                                   transactions price  \
# 0                           [pickup, delivery]    $$
# 1                           [pickup, delivery]    $$
# 2                           [pickup, delivery]    $$
# 3                                           []    $$
# 4                           [pickup, delivery]    $$
# 5                                   [delivery]    $$
# 6                                           []    $$
# 7                           [pickup, delivery]   NaN
# 8                           [pickup, delivery]   NaN
# 9                                           []    $$
# 10                          [pickup, delivery]    $$
# 11                          [pickup, delivery]    $$
# 12                          [pickup, delivery]   NaN
# 13  [pickup, restaurant_reservation, delivery]    $$
# 14                          [pickup, delivery]     $
# 15                          [pickup, delivery]   NaN
# 16                          [pickup, delivery]    $$
# 17                          [pickup, delivery]    $$
# 18                          [pickup, delivery]    $$
# 19                          [pickup, delivery]   NaN
#
#                                              location         phone  \
# 0   {'address1': '2515 Nacogdoches Rd', 'address2'...  +12108225454
# 1   {'address1': '1146 Austin Hwy', 'address2': ''...  +12108297345
# 2   {'address1': '5307 Blanco Rd', 'address2': '',...
# 3   {'address1': '1160 N Loop 1604 W', 'address2':...  +12104765072
# 4   {'address1': '6407 Blanco Rd', 'address2': '',...  +12109799110
# 5   {'address1': '5999 De Zavala Rd', 'address2': ...  +12105586707
# 6   {'address1': '8210 Broadway', 'address2': 'Ste...  +12108881155
# 7   {'address1': '15614 Huebner Rd', 'address2': '...  +12109068424
# 8   {'address1': '11720 Alamo Rnch Pkwy', 'address...  +12102815754
# 9   {'address1': '4114 Rittiman Rd', 'address2': '...  +12106579126
# 10  {'address1': '5305 McCullough Ave', 'address2'...  +12103991454
# 11  {'address1': '8503 Broadway', 'address2': 'Ste...  +12108262288
# 12  {'address1': '19141 Stone Oak Pkwy', 'address2...  +12104024042
# 13  {'address1': '2177 NW Military Hwy', 'address2...  +12102909833
# 14  {'address1': '711 South Pine St', 'address2': ...  +12107749650
# 15  {'address1': '5242 Fredericksburg Rd', 'addres...  +17264440001
# 16  {'address1': '7664 Tezel Rd', 'address2': 'Ste...  +12103141106
# 17  {'address1': '410 Valley Hi Dr', 'address2': '...  +12104639001
# 18  {'address1': '5136 Fredericksburg Rd', 'addres...  +12102675534
# 19  {'address1': '14516 Brook Hollow Blvd', 'addre...  +12102814330
#
#      display_phone      distance
# 0   (210) 822-5454   6798.844502
# 1   (210) 829-7345   6469.028248
# 2                     811.199667
# 3   (210) 476-5072  12493.997524
# 4   (210) 979-9110   2266.939173
# 5   (210) 558-6707  11349.722905
# 6   (210) 888-1155   5075.697777
# 7   (210) 906-8424  10217.566264
# 8   (210) 281-5754  20409.887105
# 9   (210) 657-9126   9846.229296
# 10  (210) 399-1454   2693.117325
# 11  (210) 826-2288   5479.588862
# 12  (210) 402-4042  14694.884811
# 13  (210) 290-9833   4298.939365
# 14  (210) 774-9650  10149.663438
# 15  (726) 444-0001   4650.089263
# 16  (210) 314-1106  14414.083065
# 17  (210) 463-9001  17603.615433
# 18  (210) 267-5534   4405.540555
# 19  (210) 281-4330  10246.929486

# %%
pip install tqdm
# Out:
# Requirement already satisfied: tqdm in c:\users\admin\anaconda3\envs\dojo-env\lib\site-packages (4.64.1)
# Requirement already satisfied: colorama in c:\users\admin\anaconda3\envs\dojo-env\lib\site-packages (from tqdm) (0.4.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import json
import math 

# Define the filename for your JSON file
JSON_FILE = "data.json"

def create_json_file(JSON_FILE,  delete_if_exists=False):
    
    ## Check if JSON_FILE exists
    file_exists = os.path.isfile(JSON_FILE)

    ## If it DOES exist:
    if file_exists == True:

        ## Check if user wants to delete if exists
        if delete_if_exists==True:

            print(f"[!] {JSON_FILE} already exists. Deleting previous file...")
            ## delete file and confirm it no longer exits.
            os.remove(JSON_FILE)
            ## Recursive call to function after old file deleted
            create_json_file(JSON_FILE,delete_if_exists=False)
        else:
            print(f"[i] {JSON_FILE} already exists.")            


    ## If it does NOT exist:
    else:

        ## INFORM USER AND SAVE EMPTY LIST
        print(f"[i] {JSON_FILE} not found. Saving empty list to new file.")

        ## CREATE ANY NEEDED FOLDERS
        # Get the Folder Name only
        folder = os.path.dirname(JSON_FILE)

        ## If JSON_FILE included a folder:
        if len(folder)>0:
            # create the folder
            os.makedirs(folder,exist_ok=True)
        ## Save empty list to start the json file
        with open(JSON_FILE,'w') as f:
            json.dump([],f)

# %%
## Create a new empty json file (exist the previous if it exists)
create_json_file(JSON_FILE, delete_if_exists=True)
## Load previous results and use len of results for offset
with open(JSON_FILE,'r') as f:
    previous_results = json.load(f)
    
## set offset based on previous results
n_results = len(previous_results)
print(f'- {n_results} previous results found.')
# use our yelp_api variable's search_query method to perform our API call
results = yelp_api.search_query(location=LOCATION,
                                term=TERM,
                               offset=n_results)
## How many results total?
total_results = results['total']
## How many did we get the details for?
results_per_page = len(results['businesses'])
# Use math.ceil to round up for the total number of pages of results.
n_pages = math.ceil((results['total']-n_results)/ results_per_page)
n_pages
# Out:
# [!] data.json already exists. Deleting previous file...
# [i] data.json not found. Saving empty list to new file.
# - 0 previous results found.
# 16

# %%
from tqdm.notebook import tqdm_notebook
import time

for i in tqdm_notebook( range(1,n_pages+1)):
    
    ## Read in results in progress file and check the length
    with open(JSON_FILE, 'r') as f:
        previous_results = json.load(f)
    ## save number of results for to use as offset
    n_results = len(previous_results)
    
    if (n_results + results_per_page) > 1000:
        print('Exceeded 1000 api calls. Stopping loop.')
        break
    
    ## use n_results as the OFFSET 
    results = yelp_api.search_query(location=LOCATION,
                                    term=TERM, 
                                    offset=n_results)
    
    
    
    ## append new results and save to file
    previous_results.extend(results['businesses'])
    
    # display(previous_results)
    with open(JSON_FILE,'w') as f:
        json.dump(previous_results,f)
    
    time.sleep(.2)
# Out:
#   0%|          | 0/16 [00:00<?, ?it/s]

# %%
# load final results
final_df = pd.read_json(JSON_FILE)
display(final_df.head(), final_df.tail())
# Out:
#                        id                                alias  \
# 0  2vfKC87Dy5Z7Umk8XMiHig  bangkok-54-thai-cuisine-san-antonio
# 1  vCXT8MFy4U8pW0ZmgoM9Xg    tongs-thai-restaurant-san-antonio
# 2  QOSNw732x0Uc-3yM9jOJfg                 thai-dee-san-antonio
# 3  KG7ORua_tyiOgOKva9rWww     thai-buri-restaurant-san-antonio
# 4  YEEThW_KpCte5TTNeFm9Cw    sawasdee-thai-cuisine-san-antonio
#
#                       name                                          image_url  \
# 0  Bangkok 54 Thai Cuisine  https://s3-media1.fl.yelpcdn.com/bphoto/vzYl-G...
# 1   Tong's Thai Restaurant  https://s3-media4.fl.yelpcdn.com/bphoto/QASd7c...
# 2                 Thai Dee  https://s3-media4.fl.yelpcdn.com/bphoto/uQCxup...
# 3     Thai Buri Restaurant  https://s3-media2.fl.yelpcdn.com/bphoto/5wUOyx...
# 4    Sawasdee Thai Cuisine  https://s3-media2.fl.yelpcdn.com/bphoto/LXPinj...
#
#    is_closed                                                url  review_count  \
# 0      False  https://www.yelp.com/biz/bangkok-54-thai-cuisi...           384
# 1      False  https://www.yelp.com/biz/tongs-thai-restaurant...           846
# 2      False  https://www.yelp.com/biz/thai-dee-san-antonio?...           605
# 3      False  https://www.yelp.com/biz/thai-buri-restaurant-...           156
# 4      False  https://www.yelp.com/biz/sawasdee-thai-cuisine...           343
#
#                                           categories  rating  \
# 0               [{'alias': 'thai', 'title': 'Thai'}]     4.5
# 1  [{'alias': 'thai', 'title': 'Thai'}, {'alias':...     4.0
# 2  [{'alias': 'thai', 'title': 'Thai'}, {'alias':...     4.0
# 3  [{'alias': 'thai', 'title': 'Thai'}, {'alias':...     4.5
# 4               [{'alias': 'thai', 'title': 'Thai'}]     4.0
#
#                                          coordinates        transactions  \
# 0  {'latitude': 29.5187911987305, 'longitude': -9...  [delivery, pickup]
# 1  {'latitude': 29.4867884, 'longitude': -98.448251}  [delivery, pickup]
# 2     {'latitude': 29.49933, 'longitude': -98.50813}  [delivery, pickup]
# 3  {'latitude': 29.606784414437673, 'longitude': ...                  []
# 4  {'latitude': 29.5136301, 'longitude': -98.5069...  [delivery, pickup]
#
#   price                                           location         phone  \
# 0    $$  {'address1': '2515 Nacogdoches Rd', 'address2'...  +12108225454
# 1    $$  {'address1': '1146 Austin Hwy', 'address2': ''...  +12108297345
# 2    $$  {'address1': '5307 Blanco Rd', 'address2': '',...
# 3    $$  {'address1': '1160 N Loop 1604 W', 'address2':...  +12104765072
# 4    $$  {'address1': '6407 Blanco Rd', 'address2': '',...  +12109799110
#
#     display_phone      distance
# 0  (210) 822-5454   6798.844502
# 1  (210) 829-7345   6469.028248
# 2                    811.199667
# 3  (210) 476-5072  12493.997524
# 4  (210) 979-9110   2266.939173
#                          id                        alias           name  \
# 303  VhoPncozSPp4vRKv6IyOaw  trilogy-pizza-san-antonio-6  Trilogy Pizza
# 304  TeMje9m4DppZVLvWMZTMbw      king-buffet-san-antonio    King Buffet
# 305  frKZSQCXBI7YigdnsJVqIQ     panera-bread-san-antonio   Panera Bread
# 306  0m8F8JuwImrED1H-SJfy3Q         panda-express-cibolo  Panda Express
# 307  EPyg1etP62ApEh_X6wLooQ   panera-bread-san-antonio-5   Panera Bread
#
#                                              image_url  is_closed  \
# 303  https://s3-media2.fl.yelpcdn.com/bphoto/takQuC...      False
# 304  https://s3-media2.fl.yelpcdn.com/bphoto/bevdOu...      False
# 305  https://s3-media2.fl.yelpcdn.com/bphoto/74AcV0...      False
# 306  https://s3-media3.fl.yelpcdn.com/bphoto/Ck5-Rf...      False
# 307  https://s3-media1.fl.yelpcdn.com/bphoto/9TSffL...      False
#
#                                                    url  review_count  \
# 303  https://www.yelp.com/biz/trilogy-pizza-san-ant...           512
# 304  https://www.yelp.com/biz/king-buffet-san-anton...           403
# 305  https://www.yelp.com/biz/panera-bread-san-anto...           149
# 306  https://www.yelp.com/biz/panda-express-cibolo?...            58
# 307  https://www.yelp.com/biz/panera-bread-san-anto...           183
#
#                                             categories  rating  \
# 303  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.5
# 304  [{'alias': 'buffets', 'title': 'Buffets'}, {'a...     3.0
# 305  [{'alias': 'sandwiches', 'title': 'Sandwiches'...     3.0
# 306  [{'alias': 'chinese', 'title': 'Chinese'}, {'a...     2.0
# 307  [{'alias': 'sandwiches', 'title': 'Sandwiches'...     3.0
#
#                                            coordinates        transactions  \
# 303  {'latitude': 29.6253818, 'longitude': -98.4955...  [delivery, pickup]
# 304   {'latitude': 29.485432, 'longitude': -98.607147}  [delivery, pickup]
# 305      {'latitude': 29.49797, 'longitude': -98.4686}  [delivery, pickup]
# 306     {'latitude': 29.57334, 'longitude': -98.24141}  [delivery, pickup]
# 307  {'latitude': 29.4383245111094, 'longitude': -9...  [delivery, pickup]
#
#     price                                           location         phone  \
# 303    $$  {'address1': '19141 Stone Oak Pkwy', 'address2...  +12104041818
# 304    $$  {'address1': '6200 Bandera Rd', 'address2': ''...  +12106478888
# 305     $  {'address1': '999 E Basse Road', 'address2': '...  +12108227000
# 306     $  {'address1': '713 Cibolo Valley Dr', 'address2...  +12105661138
# 307    $$  {'address1': '8531 State Highway 151', 'addres...  +12105212399
#
#       display_phone      distance
# 303  (210) 404-1818  14673.801489
# 304  (210) 647-8888   9032.131314
# 305  (210) 822-7000   4340.837908
# 306  (210) 566-1138  28206.481582
# 307  (210) 521-2399  14960.515815

# %%
# check for duplicate ID's 
final_df.duplicated(subset='id').sum()
# Out:
# 0

# %%
## Drop duplicate ids and confirm there are no more duplicates
final_df = final_df.drop_duplicates(subset='id')
final_df.duplicated(subset='id').sum()
# Out:
# 0

# %%
import os

# Define the folder name you want to create
folder_name = 'Data'

# Check if the folder already exists
if not os.path.exists(folder_name):
    os.makedirs(folder_name)
    print(f"Folder '{folder_name}' created.")
else:
    print(f"Folder '{folder_name}' already exists.")


# save the final results to a compressed csv
final_df.to_csv('Data/SanAntonioThai.gz', compression='gzip',index=False)
# Out:
# Folder 'Data' already exists.

# %%
# List files in the folder
file_list = os.listdir(folder_name)

# Print the list of files
print("Files in the 'Data' folder:")
for file in file_list:
    print(file)
# Out:
# Files in the 'Data' folder:
# SanAntonioThai.gz
